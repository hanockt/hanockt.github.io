# %% [markdown]
# # Analysis of Povety in America and the Implications of Race

# %% [markdown]
# ## By Mana Gammi and Hanock Tsegaye

# %% [markdown]
# ## Introduction

# %% [markdown]
# Britannica defines poverty as "the state of one who lacks a usual or socially acceptable amount of money or material possessions" causing thme to "lack the means to satisfy their basic needs" (1). While this definition is relatively vague and open to interpretation, especially in regard to what constitues as a basic need, the underlying gist is that a person who lives in poverty cannot pay for food, clean water, clothing, and shelter. While the measure of poverty varies across nations, where in its extreme it's recognized as living on less than $1.90 per day in the USA, the marker for living in poverty is not as low as you may think (2). In fact, roughly 11.6% of the US population lives in poverty (as of January 2021) -- that's 37.9 million Americans (3).
#
# People generally associate poverty exclusively to income, but that's a tremendous misconstruction. In reality, poverty can be measured across 3 dimensions: health, education, and standard of living (2). This means when examining poverty, professionals look at child mortality rates and nutrition, school attendance, and electricity, sanitation, and housing, to give a few examples. so, poverty is not only what you can and cannot buy, but likewise an examination of the quality of one's overall human exeperience.
#
# Poverty can be a difficult topic of study as it's not only difficult to define, but also difficult to generalize. There are many factors to consider when examining poverty rates in the USA. This includes age, gender, immigration status, familial status, ethnicity, geographical location, disability, race, and income, just to name a few examples, and it's increasingly difficult when you take into account that the aformentioned factors are not independent --  in most cases they intersect. While we recognize all the factors mentioned above are important, in this project we will only look at race,income, and location for the sake of being as thorough as we can.
#
# The purpose of this project is to analyze poverty across America in the context of race. In other words, we're looking to see if there's a trend between poverty status and the race in which one identifies as to see if race is an indicator of poverty, but also we'll look closely at income and state in our research.
#
# Do certain races tend to have higher poverty rates than others? On the flip side, do certain races have have lower rates than others? The goal in asking these questions and making the differentiation based on race is to indubitabily inidentify social and economic inequalities in American society. Certain members of our country endure systematic discrimination on account of their race and this keeps them from recieving the same opprotunities and having the same experiences as their counterparts. If there is indeed a correaltion between poverty and race that would mean many Americans are enduring an injustice that they'll like never be able to break away from. And because poverty is a cycle, families will be affected across generations.
#
# Once we can recognize that these inequalities exist, and prove so beyond a shadow of a doubt, we can then take steps to rectify the error.
#
# For the purpose of this study we recognize the following 5 groups as races: White, Black, Asian, Native Hawaiian or Pacific Islander, American Indian or Alaska Native, and we'll look at poverty statistics collected by the US government, as far back as 1959 and as recently as 2022, that record these races so that can can make direct generalizations.
#
# We've collected tables that look at per capita income, poverty rates in regards to the total US population, poverty across states, and poverty status by race which we'll thoroughly analyze to make a confident hypothesis. We'll then use linear regression and machine learning to accept or reject this hypothesis.
#
# This tutorial will walk you through the entire data science pipeline, which includes the following 5 stages:
#
# 1. Data Collection
# 2. Data Processing
# 3. Exploratory Analysis and Data Visualization
# 4. Analysis, Hypothesis Testing, and Machine Learning
# 5. and lastly, Insight and Policy Decision
#
# Enjoy!
#
# Sources:
# 1. Britannica, T. Editors of Encyclopaedia (2023, April 6). poverty. Encyclopedia Britannica. https://www.britannica.com/topic/poverty
# 2. https://www.worldvision.ca/stories/child-sponsorship/what-is-poverty
# 3. https://www.cnbc.com/2023/03/07/why-poverty-might-be-far-worse-in-the-us-than-its-reported.html#:~:text=As%20of%20January%202021%2C%2037.9,the%20United%20States%20Census%20Bureau

# %% [markdown]
# Here are the packages we'll need for the tutorial.

# %%
import seaborn as sb
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import statistics
import sklearn.linear_model as slm
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import statsmodels.formula.api as smf
import warnings
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Collection, Cleaning and Processing

# %% [markdown]
# Our tutorial begins with collecting, processing and cleaning out data. As you can see, we've combined the first 2 stages of the data science pipeline. We've done this because collecting the data and processing it as you go is often the most organized and consistent course of action. Once you have your data, you might as well process and clean it while its right there. This prevents forgetting steps in cleaning data and data loss that can occur when switching back and forth between dataframes.
#
# At this point you're probably wondering why to even bother cleaning data. Here are several reasons why its important:
#
# - You can present your data in a more human readable form, which allows for easier and more accurate interpretation of data.
# - It ensures data is in the correct format to be used later on.
#     - For example, making sure dollars are integers or floats so we can perform calculations on them.
# - It makes the data more concise because we can drop columns that are not useful and rows that are incomplete (such as because of null values).
# - Going back to add changes when necessary is easier when all the code cleaning is with the table collection because everything is in one place.

# %% [markdown]
# The next 3 tables were collected by doing a few google searches and then downloading the tables as csv's and excel sheets. In these formats, it's quick and easy to read the data into a dataframe using pandas.
#
# This website is incredibly helpful for the work we're doing next: https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html

# %% [markdown]
# ### Table 1: CPS Population and Per Capita Money Income, All People: 1967 to 2021

# %% [markdown]
# The first table was downloaded as a CSV so we can us pandas read_csv to read it into a dataframe. The documentatio to explain how the funciton works is here : https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %%
data1 = pd.read_csv("p01ar.csv", header=6) #header starts in row 6
print(data1.dtypes)
data1.head(7)
# this part constitues as data collection
# Out:
# Year                  object
# Number (thousands)    object
# Per capita income     object
# Unnamed: 3            object
# dtype: object
#         Year Number (thousands) Per capita income     Unnamed: 3
# 0        NaN                NaN  Current\ndollars  2021\ndollars
# 1       2021            328,722            41,285         41,285
# 2  2020 (41)            328,059            38,931         40,749
# 3       2019            325,268            39,156         41,496
# 4       2018            324,356            36,080         38,929
# 5  2017 (40)            323,144            35,048         38,737
# 6       2017            323,156            34,489         38,119

# %% [markdown]
# Here's what the first 7 rows of the dataframe (data1) look like. Immediately, there are several issues.
#
# - Frist, there are 2 rows of heading which makes the table confusing to read. 'Current\ndollars' and '2021\ndollars are subsets' of Per capita income. They'll need to be combined so there's only 1 row of heading and 4 columns. Then, the extra rows can be dropped. We'll use pandas rename() to rename 'Per capita income' and 'Unnamed 3:' to include 'Current\ndollars' and '2021\ndollars. Then we'll use pandas drop() to drop the first row since it doesn't hold data.
#
# - Next, the 'Year' column has extra values in some of the rows. These values must be removed so that there's only the years represented in that column. We want this because we don't need those values for the purposes of our study and keeping them will complicate graphs we'll make later on.
#
# - Last, using the dtypes feature of the dataframe, we can see that all the values are object. It would be better is they were all numerical -- whether as integers and floats -- so we can perform caluclations on them later. To do this, we'll first need to remove non-numerical characters from each column using pandas apply() and lambda functions. Then we can use pandas astype() function to change the columns type. Information for this function is found here: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html.
#
# Making these changes is the beginning of the Data Processing stage for this table

# %%
data1 = data1.rename(columns = {"Per capita income": "Current PCI in Dollars", "Unnamed: 3":"2021 PCI in Dollars"}) #rename headers
data1 = data1.drop(index = [0]) # now can drop the first row 
data1.head(7)
#Note: PCI == Per Capita Income
# Out:
#         Year Number (thousands) Current PCI in Dollars 2021 PCI in Dollars
# 1       2021            328,722                 41,285              41,285
# 2  2020 (41)            328,059                 38,931              40,749
# 3       2019            325,268                 39,156              41,496
# 4       2018            324,356                 36,080              38,929
# 5  2017 (40)            323,144                 35,048              38,737
# 6       2017            323,156                 34,489              38,119
# 7       2016            320,372                 33,205              37,490

# %%
data1['Year'] = data1['Year'].apply(lambda item : (str(item[:4])) if str.__contains__(str(item),'(') == True else item) #want to remove the numbers in paranthesis next to the years
data1['Number (thousands)'] = data1['Number (thousands)'].apply(lambda item : (item.replace(",", "") if str.__contains__(str(item),',') == True else item))
data1['Current PCI in Dollars'] = data1['Current PCI in Dollars'].apply(lambda item : (item.replace(",", "") if str.__contains__(str(item),',') == True else item))
data1['2021 PCI in Dollars'] = data1['2021 PCI in Dollars'].apply(lambda item : (item.replace(",", "") if str.__contains__(str(item),',') == True else item))
data1 = data1.astype({'Number (thousands)': int, 'Current PCI in Dollars': int, '2021 PCI in Dollars':int, 'Year': int})
print(data1.dtypes)
data1.head(10)
# Out:
# Year                      int32
# Number (thousands)        int32
# Current PCI in Dollars    int32
# 2021 PCI in Dollars       int32
# dtype: object
#     Year  Number (thousands)  Current PCI in Dollars  2021 PCI in Dollars
# 1   2021              328722                   41285                41285
# 2   2020              328059                   38931                40749
# 3   2019              325268                   39156                41496
# 4   2018              324356                   36080                38929
# 5   2017              323144                   35048                38737
# 6   2017              323156                   34489                38119
# 7   2016              320372                   33205                37490
# 8   2015              318868                   31653                36198
# 9   2014              316168                   30176                34569
# 10  2013              313443                   30027                34980

# %% [markdown]
# Notice: changes need to be reassigned to the dataframe, otherwise the change will be lost!

# %% [markdown]
# In the segment above, we had to remove ',' from the last 3 columns so that they could be turned into ints.

# %% [markdown]
# ### Table 2: People in Poverty by Nativity: 1993 to 2021

# %% [markdown]
# This table was downloaded as a excel sheet, so we can read it in using panda's read_excel. Documentatio for this function can be found here:
# https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html.

# %%
data2 = pd.read_excel("hstpov16.xlsx", header = 3) #note: 2 levels of headers
data2.head()
# Out:
#        Year All people         Unnamed: 2          Unnamed: 3  Native  \
# 0       NaN        NaN                NaN                 NaN     NaN
# 1       NaN      Total  Number in poverty  Percent in poverty   Total
# 2      2021     328191              37933                11.6  281383
# 3  2020 (1)     327570              37548                11.5  282408
# 4      2019     324754              33984                10.5  279867
#
#           Unnamed: 5          Unnamed: 6 Foreign-born         Unnamed: 8  \
# 0                NaN                 NaN        Total                NaN
# 1  Number in poverty  Percent in poverty        Total  Number in poverty
# 2              31083                  11        46808               6850
# 3              31485                11.1        45162               6063
# 4              28342                10.1        44886               5643
#
#            Unnamed: 9          Unnamed: 10        Unnamed: 11  \
# 0                 NaN  Naturalized citizen                NaN
# 1  Percent in poverty                Total  Number in poverty
# 2                14.6                22874               2428
# 3                13.4                22800               2087
# 4                12.6                22746               2038
#
#           Unnamed: 12    Unnamed: 13        Unnamed: 14         Unnamed: 15
# 0                 NaN  Not a citizen                NaN                 NaN
# 1  Percent in poverty          Total  Number in poverty  Percent in poverty
# 2                10.6          23934               4422                18.5
# 3                 9.2          22362               3977                17.8
# 4                   9          22140               3605                16.3

# %% [markdown]
# This is dataframe is extremely confusing to look at because of the way the information was organzied. The current header distinguished by people groups, the first row distinguished by citizenship, and the next row labels what information is held in that column.
#
# We're going to do several things.
#
# - Frist, we're going to remove all the columns except the first 4. Evidently, that's a lot of coluns to remove, for simplicity, we'll make a new dataframe and use pandas to extract the 4 four columns from the old dataframe into the new one.
#
# - Next, as we did with the first table, we're going to remove extra values in the year column.
#
# - After, we're going to rename our columns with the table names at row index 1.
#
# - Lastly, we're going to drop the first 2 rows because they dont store data.

# %%
#just want Native groups
dataNew = data2.loc[:32, ["Year","Native","Unnamed: 5", "Unnamed: 6"]]
dataNew['Year'] = dataNew['Year'].apply(lambda item : (str(item[:4])) if str.__contains__(str(item),'(') == True else item) 
#want to remove the numbers in paranthesis next to the years
dataNew = dataNew.rename(columns = {"Native": "Total", "Unnamed: 5":"Number in Poverty", "Unnamed: 6": "Percent in Poverty"}) #rename headers
dataNew = dataNew.drop(index = [0,1])
print(dataNew.dtypes)
dataNew.head(10)
# Out:
# Year                  object
# Total                 object
# Number in Poverty     object
# Percent in Poverty    object
# dtype: object
#     Year   Total Number in Poverty Percent in Poverty
# 2   2021  281383             31083                 11
# 3   2020  282408             31485               11.1
# 4   2019  279867             28342               10.1
# 5   2018  278051             31828               11.4
# 6   2017  277131             33143                 12
# 7   2017  277158             33095               11.9
# 8   2016  276089             33999               12.3
# 9   2015  275398             35973               13.1
# 10  2014  273628             38871               14.2
# 11  2013  272423             38831               14.3

# %% [markdown]
# Here, we've printed the data types of the remaining columns and once again, they're all objects. Lets change them once again to numerical types so we can perform calculations on them later.

# %%
dataNew = dataNew.astype({'Year':'int', 'Total':int, 'Number in Poverty':int, 'Percent in Poverty':float})
print(dataNew.dtypes)
# Out:
# Year                    int32
# Total                   int32
# Number in Poverty       int32
# Percent in Poverty    float64
# dtype: object

# %% [markdown]
# ### Table 3: Poverty Status of People by Family Relationship, Race, and Hispanic Origin: 1959 to 2021

# %% [markdown]
# This table was downloaded as an excel sheet, so we can read it in using panda's read_excel. You can look at the same link above.

# %%
data3 = pd.read_excel("hstpov2 .xlsx", header = 4 ) #several headers, first one starts on line 4
print(data3.dtypes)
data3.head()
# Note, population is in thousands!
# Out:
# Year                     object
# All people               object
# Unnamed: 2               object
# Unnamed: 3               object
# People in families       object
# Unnamed: 5               object
# Unnamed: 6               object
# Unnamed: 7               object
# Unnamed: 8               object
# Unnamed: 9               object
# Unrelated individuals    object
# Unnamed: 11              object
# Unnamed: 12              object
# dtype: object
#        Year All people     Unnamed: 2 Unnamed: 3 People in families  \
# 0       NaN        NaN            NaN        NaN       All families
# 1       NaN      Total  Below poverty        NaN              Total
# 2       NaN        NaN         Number    Percent                NaN
# 3      2021     328191          37933       11.6             263764
# 4  2020 (1)     327570          37548       11.5             264437
#
#       Unnamed: 5 Unnamed: 6  \
# 0            NaN        NaN
# 1  Below poverty        NaN
# 2         Number    Percent
# 3          25077        9.5
# 4          25232        9.5
#
#                                           Unnamed: 7     Unnamed: 8  \
# 0  Families with female householder, no spouse pr...            NaN
# 1                                              Total  Below poverty
# 2                                                NaN         Number
# 3                                              48476          12264
# 4                                              48984          12469
#
#   Unnamed: 9 Unrelated individuals    Unnamed: 11 Unnamed: 12
# 0        NaN                   NaN            NaN         NaN
# 1        NaN                 Total  Below poverty         NaN
# 2    Percent                   NaN         Number     Percent
# 3       25.3                 63398          12513        19.7
# 4       25.5                 62097          11963        19.3

# %% [markdown]
# This table is a mess so we're going to do several things and in this order.
#
# 1. Rename columns so they're indicative of the informaiton they hold. Like the previous tables, it looks like the headers are multiple rows so we need to look at the first few rows. We're going to use the same pandas rename() funciton.
# 2. Drop columns we dont need. We're not distinguishing by family status, so we'll remove the columns pertaining to that. We'll again pandas drop() again.
# 3. Create new dataframes so that the information can be seperated by race. You cant tell from the table above, but the excel_sheet we downloaded is composed of several tables. So by using indices and pandas iloc, we can take slices of the dataframe and make a new dataframe out if it.

# %%
data3 = data3.rename(columns = {"All people" : "Total Number", "Unnamed: 2": "Number Below Poverty", 
                                "Unnamed: 3": "Percent Below Poverty", "Unnamed: 7":"Female HoH", "Unnamed: 9": "Percent Female HoH Below Poverty"})
data3 = data3.loc[:, ["Year", "Total Number","Number Below Poverty","Percent Below Poverty", "Female HoH", "Percent Female HoH Below Poverty"]]
data3['Year'] = data3['Year'].apply(lambda item : (str(item[:4])) if str.__contains__(str(item),'(') == True else item) #want to remove the numbers in paranthesis next to the years


data3.head()

# not gonna drop first few rows bc affects rest of new dataframes with indices
# Out:
#    Year Total Number Number Below Poverty Percent Below Poverty  \
# 0   NaN          NaN                  NaN                   NaN
# 1   NaN        Total        Below poverty                   NaN
# 2   NaN          NaN               Number               Percent
# 3  2021       328191                37933                  11.6
# 4  2020       327570                37548                  11.5
#
#                                           Female HoH  \
# 0  Families with female householder, no spouse pr...
# 1                                              Total
# 2                                                NaN
# 3                                              48476
# 4                                              48984
#
#   Percent Female HoH Below Poverty
# 0                              NaN
# 1                              NaN
# 2                          Percent
# 3                             25.3
# 4                             25.5

# %% [markdown]
# Important note: we're not dropping any rows because we're going to 'slice' the dataframe anyway and this would throw off indices we're going to use.

# %% [markdown]
# Next, the first table in the dataframe holds information across all races. We're going to extract just that table and save it in a new dataframe.

# %%
#splitting up data into different tables for each race
dataAllRaces= data3.iloc[3:68,:]
dataAllRaces
# Out:
#     Year Total Number Number Below Poverty Percent Below Poverty Female HoH  \
# 3   2021       328191                37933                  11.6      48476
# 4   2020       327570                37548                  11.5      48984
# 5   2019       324754                33984                  10.5      46255
# 6   2018       323847                38146                  11.8      46660
# 7   2017       322548                39564                  12.3      47517
# ..   ...          ...                  ...                   ...        ...
# 63  1963       187258                36436                  19.5          N
# 64  1962       184276                38625                    21          N
# 65  1961       181277                39628                  21.9          N
# 66  1960       179503                39851                  22.2          N
# 67  1959       176557                39490                  22.4          N
#
#    Percent Female HoH Below Poverty
# 3                              25.3
# 4                              25.5
# 5                              24.3
# 6                              26.8
# 7                              28.5
# ..                              ...
# 63                             47.7
# 64                             50.3
# 65                             48.1
# 66                             48.9
# 67                             49.4
#
# [65 rows x 6 columns]

# %% [markdown]
# Now we're going to do the same for each race. We'll extract the correct rows by looking at the indices of the excel sheet and then save them in a new dataframe. We actually will not end up using it as we already have a table that provides the same info.
#
# For these dataframes, we'll also make a new column called 'Race' and add the correct race for each dataframe. After, we'll drop rows that are empty using dropna().

# %%
dataWhite = data3.iloc[73:143,:]
dataWhite['Race'] = 'White'
dataWhite= dataWhite.dropna()
dataWhite.head()
# Out:
#     Year Total Number Number Below Poverty Percent Below Poverty Female HoH  \
# 73  2021       248909                24919                    10      28961
# 74  2020       249083                25183                  10.1      29829
# 75  2019       248086                22512                   9.1      27848
# 76  2018       247634                24945                  10.1      28375
# 77  2017       247255                26026                  10.5      28671
#
#    Percent Female HoH Below Poverty   Race
# 73                             22.7  White
# 74                             23.4  White
# 75                             21.6  White
# 76                             24.6  White
# 77                             25.8  White

# %%
dataBlack = data3.iloc[236:300,:]
dataBlack['Race'] = 'Black'
dataBlack = dataBlack.dropna()
dataBlack.head()
# Out:
#      Year Total Number Number Below Poverty Percent Below Poverty Female HoH  \
# 236  2021        43976                 8583                  19.5      14035
# 237  2020        43694                 8556                  19.6      14082
# 238  2019        42965                 8073                  18.8      13939
# 239  2018        42773                 8884                  20.8      13500
# 240  2017        42477                 9224                  21.7      13986
#
#     Percent Female HoH Below Poverty   Race
# 236                             30.8  Black
# 237                             29.9  Black
# 238                             29.5  Black
# 239                             31.7  Black
# 240                             34.4  Black

# %%
dataAsian= data3.iloc[332:374,:]
dataAsian['Race'] = 'Asian/Pacific Islander'
dataAsian = dataAsian.dropna()
dataAsian.head()
# Out:
#      Year Total Number Number Below Poverty Percent Below Poverty Female HoH  \
# 332  2021        20676                 1922                   9.3       1989
# 333  2020        20352                 1645                   8.1       1783
# 334  2019        19926                 1464                   7.3       1576
# 335  2018        19768                 1996                  10.1       1686
# 336  2017        19526                 1891                   9.7       1715
#
#     Percent Female HoH Below Poverty                    Race
# 332                             15.1  Asian/Pacific Islander
# 333                             17.4  Asian/Pacific Islander
# 334                             16.1  Asian/Pacific Islander
# 335                             19.4  Asian/Pacific Islander
# 336                             16.8  Asian/Pacific Islander

# %%
dataNA= data3.iloc[406:448,:]
dataNA['Race'] = 'American Indian/AN' #Native American, Alaska Native
dataNA = dataNA.dropna()
dataNA.head()
# Out:
#      Year Total Number Number Below Poverty Percent Below Poverty Female HoH  \
# 406  2021         4109                  998                  24.3        999
# 407  2020         3950                  791                    20        877
# 408  2019         3735                  677                  18.1        701
# 409  2018         3663                  808                  22.1        828
# 410  2017         3616                  790                  21.8        888
#
#     Percent Female HoH Below Poverty                Race
# 406                             43.5  American Indian/AN
# 407                             34.6  American Indian/AN
# 408                               33  American Indian/AN
# 409                             28.1  American Indian/AN
# 410                             33.7  American Indian/AN

# %%
dataHispanic = data3.iloc[480:532,:] 
dataHispanic['Race'] = 'Hispanic'
dataHispanic = dataHispanic.dropna()
dataHispanic.head()
# Out:
#      Year Total Number Number Below Poverty Percent Below Poverty Female HoH  \
# 480  2021        62482                10690                  17.1      12382
# 481  2020        61769                10520                    17      12856
# 482  2019        60602                 9545                  15.7      12248
# 483  2018        59957                10526                  17.6      11939
# 484  2017        59051                10816                  18.3      12155
#
#     Percent Female HoH Below Poverty      Race
# 480                             30.3  Hispanic
# 481                             30.1  Hispanic
# 482                             28.7  Hispanic
# 483                             31.1  Hispanic
# 484                             35.2  Hispanic

# %% [markdown]
# Hispanic is not technically a race but we'll take note of it.

# %% [markdown]
# Now, we're going to add all the dataframes together by using pandas concat() to basically stack all the dataframes. We want this because having all the data in one table makes it easier to use.
#
# We're also going to change column types so graphing later on is easier.

# %%
# combining all the DFs
finalDF = pd.concat([ dataHispanic ,dataWhite , dataAsian , dataBlack, dataNA], ignore_index=True, axis=0)
finalDF['Percent Below Poverty'] = finalDF['Percent Below Poverty'].apply(lambda item: float(item))
finalDF['Percent Female HoH Below Poverty'] = finalDF['Percent Female HoH Below Poverty'].astype(float)
finalDF['Percent Female HoH'] = (finalDF['Female HoH'].astype(int) / finalDF['Total Number']) * 100
finalDF= finalDF.astype({'Year':'int', 'Total Number':int, 'Number Below Poverty':int, 'Percent Below Poverty':float})

finalDF
# Out:
#      Year  Total Number  Number Below Poverty  Percent Below Poverty  \
# 0    2021         62482                 10690                   17.1
# 1    2020         61769                 10520                   17.0
# 2    2019         60602                  9545                   15.7
# 3    2018         59957                 10526                   17.6
# 4    2017         59051                 10816                   18.3
# ..    ...           ...                   ...                    ...
# 235  1991          1793                   562                   31.3
# 236  1990          1560                   444                   28.5
# 237  1989          1445                   345                   23.9
# 238  1988          1454                   440                   30.2
# 239  1987          1345                   387                   28.8
#
#     Female HoH  Percent Female HoH Below Poverty                Race  \
# 0        12382                              30.3            Hispanic
# 1        12856                              30.1            Hispanic
# 2        12248                              28.7            Hispanic
# 3        11939                              31.1            Hispanic
# 4        12155                              35.2            Hispanic
# ..         ...                               ...                 ...
# 235        347                              59.6  American Indian/AN
# 236        334                              54.1  American Indian/AN
# 237        269                              56.5  American Indian/AN
# 238        269                              42.9  American Indian/AN
# 239        325                              48.4  American Indian/AN
#
#     Percent Female HoH
# 0            19.816907
# 1            20.813029
# 2            20.210554
# 3            19.912604
# 4            20.583902
# ..                 ...
# 235           19.35304
# 236          21.410256
# 237          18.615917
# 238          18.500688
# 239          24.163569
#
# [240 rows x 8 columns]

# %% [markdown]
# Now all the data is together and has a column that'll allow us to track race and poverty across years.

# %% [markdown]
# ### Table 4: Poverty Rate by Race and Ethnicity

# %% [markdown]
# This table was also downloaded as a CSV, so we can again use pandas read_csv

# %%
povByRace = pd.read_csv("povRace.csv", header=2)
povByRace.head(20)
# Out:
#                 Location  White  Black  Hispanic  \
# 0          United States  0.095  0.217     0.176
# 1                Alabama  0.119  0.247     0.244
# 2                 Alaska  0.078  0.251     0.130
# 3                Arizona  0.089  0.168     0.171
# 4               Arkansas  0.137  0.272     0.218
# 5             California  0.090  0.194     0.152
# 6               Colorado  0.077  0.177     0.148
# 7            Connecticut  0.068  0.145     0.196
# 8               Delaware  0.073  0.170     0.202
# 9   District of Columbia  0.050  0.280     0.090
# 10               Florida  0.100  0.202     0.157
# 11               Georgia  0.095  0.203     0.197
# 12                Hawaii  0.118  0.257     0.135
# 13                 Idaho  0.101    NaN     0.139
# 14              Illinois  0.085  0.243     0.143
# 15               Indiana  0.101  0.204     0.185
# 16                  Iowa  0.094  0.312     0.172
# 17                Kansas  0.096  0.277     0.180
# 18              Kentucky  0.153  0.248     0.261
# 19             Louisiana  0.123  0.321     0.208
#
#     Asian/Native Hawaiian and Pacific Islander  American Indian/Alaska Native  \
# 0                                        0.102                          0.259
# 1                                        0.114                          0.144
# 2                                          NaN                          0.206
# 3                                        0.111                          0.348
# 4                                        0.116                          0.117
# 5                                        0.101                          0.225
# 6                                        0.082                          0.156
# 7                                        0.080                            NaN
# 8                                        0.072                            NaN
# 9                                        0.174                            NaN
# 10                                       0.098                          0.215
# 11                                       0.090                          0.270
# 12                                       0.096                            NaN
# 13                                       0.143                          0.173
# 14                                       0.104                          0.284
# 15                                       0.170                            NaN
# 16                                       0.139                          0.411
# 17                                       0.099                            NaN
# 18                                       0.096                          0.424
# 19                                       0.188                          0.262
#
#     Multiple Races  Total  Footnotes
# 0            0.141  0.128        1.0
# 1            0.184  0.160        NaN
# 2            0.124  0.110        NaN
# 3            0.105  0.129        NaN
# 4            0.157  0.164        NaN
# 5            0.117  0.123        NaN
# 6            0.116  0.099        NaN
# 7            0.101  0.101        NaN
# 8            0.180  0.112        NaN
# 9            0.158  0.165        NaN
# 10           0.137  0.131        NaN
# 11           0.152  0.141        NaN
# 12           0.125  0.113        NaN
# 13           0.153  0.112        NaN
# 14           0.140  0.120        NaN
# 15           0.167  0.121        NaN
# 16           0.146  0.111        NaN
# 17           0.177  0.120        NaN
# 18           0.194  0.165        NaN
# 19           0.262  0.196        NaN

# %% [markdown]
# Here we can see that the 'Footnotes` column is totally empty, so lets remove that.
#
# But more complicatedly, there a empty values across other rows and columns -- for now we'll leave them as is. We take care of this later on.

# %%
povByRace = povByRace.drop(columns = {"Footnotes"}) #dont need
povByRace.head()
# Out:
#         Location  White  Black  Hispanic  \
# 0  United States  0.095  0.217     0.176
# 1        Alabama  0.119  0.247     0.244
# 2         Alaska  0.078  0.251     0.130
# 3        Arizona  0.089  0.168     0.171
# 4       Arkansas  0.137  0.272     0.218
#
#    Asian/Native Hawaiian and Pacific Islander  American Indian/Alaska Native  \
# 0                                       0.102                          0.259
# 1                                       0.114                          0.144
# 2                                         NaN                          0.206
# 3                                       0.111                          0.348
# 4                                       0.116                          0.117
#
#    Multiple Races  Total
# 0           0.141  0.128
# 1           0.184  0.160
# 2           0.124  0.110
# 3           0.105  0.129
# 4           0.157  0.164

# %%
print(povByRace.dtypes) 
# want to double check the datatypes of each column are appropriate for the data they hold so they can be best used later
# Out:
# Location                                       object
# White                                         float64
# Black                                         float64
# Hispanic                                      float64
# Asian/Native Hawaiian and Pacific Islander    float64
# American Indian/Alaska Native                 float64
# Multiple Races                                float64
# Total                                         float64
# dtype: object

# %% [markdown]
# These types are acceptable

# %% [markdown]
# ### Table 5 : Median Household Income by Race

# %% [markdown]
# This next table we're going to perform webscrapping to obtain. Here's how the process works:
#
# 1. store the URL of the webpage that stores the desired table.
# 2. Use pythons requests packages get() function to send a GET request to the specified url. Here's a website that explains how the function works well : https://www.w3schools.com/python/ref_requests_get.asp.
# 3. Use pythons BeautifulSoup package to parse the website. Then we can use prettify() the read through the webpage's html code and see where our table begins. We've commented it out as the result is very long and tedious to scroll through.
# 4. use findall() to get the table and then read_html to read the table into a dataframe. Notice the result of read_html is an array -- we want the first element.
#
#
# Here's a webpage that has examples of the entire process : https://www.geeksforgeeks.org/implementing-web-scraping-python-beautiful-soup/.

# %%
url = 'https://www.pgpf.org/blog/2023/02/income-and-wealth-in-the-united-states-an-overview-of-recent-data'

medByRace = requests.get(url)

soup1 = BeautifulSoup(medByRace.content, 'html.parser')
# print(soup1.prettify())

table1 = soup1.findAll('table') #returns an array of tall the instances of 'table' in the webpage
tables = pd.read_html(str(table1))
df = tables[2] #the third table on the webpage is the one we want
print(df.dtypes)
df
# Out:
# Race/Ethnicity of Household Head               object
# 2020 Median Household Income (2021 dollars)    object
# 2021 Median Household Income                   object
# dtype: object
#   Race/Ethnicity of Household Head  \
# 0            All races/ethnicities
# 1                            Asian
# 2              White, not Hispanic
# 3              Hispanic (any race)
# 4                            Black
#
#   2020 Median Household Income (2021 dollars) 2021 Median Household Income
# 0                                     $71,186                      $70,784
# 1                                     $99,622                     $101,418
# 2                                     $78,912                      $77,999
# 3                                     $58,015                      $57,981
# 4                                     $48,175                      $48,297

# %%
df['2020 Median Household Income (2021 dollars)'] = df['2020 Median Household Income (2021 dollars)'].apply(lambda x: x[1:].replace(",",'')).astype(float)
df['2021 Median Household Income'] = df['2021 Median Household Income'].apply(lambda x: x[1:].replace(",",'')).astype(float)
df.head()
# Out:
#   Race/Ethnicity of Household Head  \
# 0            All races/ethnicities
# 1                            Asian
# 2              White, not Hispanic
# 3              Hispanic (any race)
# 4                            Black
#
#    2020 Median Household Income (2021 dollars)  2021 Median Household Income
# 0                                      71186.0                       70784.0
# 1                                      99622.0                      101418.0
# 2                                      78912.0                       77999.0
# 3                                      58015.0                       57981.0
# 4                                      48175.0                       48297.0

# %% [markdown]
# ## Exploratory Analysis and Data Visualization

# %% [markdown]
# Now that the data is clean and human readable, we can try to analyze and visualize it. This will help us detect patterns and trends that'll make way for generalizations.

# %% [markdown]
# ### Poverty and Time

# %% [markdown]
# First, we're going to plot 'Percent in Poverty' vs 'Year' using matplot libs scatter(). Documentation for this function can be found here: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html.
#
# We're doing this to see if there's a trend between time and poverty, meaning, how has poverty changed in the last few decades?

# %%
fig, ax = plt.subplots(figsize=(7, 7))
plt.scatter( x= dataNew['Year'], y =dataNew['Percent in Poverty'])

# %% [markdown]
# The results of our scatter plot show that Poverty vs Year does not a have a linear, positive relationship as we had expected. This means that there is not a constant rate of change between time and poverty and we cannot create a linear regression of the relationship
#
# It's likely that world events are a major contributor to the fluctuations in poverty. For example, just before 2010 you see the beginning of an increase inpoverty rates that contines another 5 years. This corresponsd to the 2008 recession that would likely have been a monumental trigger for poverty.

# %% [markdown]
# ### Poverty and Race

# %% [markdown]
# For our next plot we're going to try get a visual of race in regards to poverty.
#
# When creating the graph, 'Race' is the independent variable and 'Perent Below Poverty' is the dependet variable. Aka Percent Below Poverty Vs. Race
#
# For better visualization they are distinguishable by color, which was done using a dictionary that stored race (key) and colors (value).
#
# The make the table, we first used pandas groupby() to make groups by race. Then we iterated through these groups to print the rows according to their key (race) so that they have the right color.
#
# We used matplotlib plot() to make a scatter plot of the data. Documentation can be found here: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html.
#
# x is set to 'Race' and y to 'Percent Below Poverty'.

# %%
colors = {"American Indian/AN" : "green", "Hispanic" : "red", "Black" : "blue", "White": "purple" , "Asian/Pacific Islander" : "orange"}

fig, ax = plt.subplots(figsize=(7, 7))
groupedDF = finalDF.groupby(['Race'])
for key, group in groupedDF :
        group.plot(ax = ax, kind='scatter', y='Percent Below Poverty', x='Race', label=key,color=colors[key])

plt.xticks(rotation=45, ha='right') #so that the x-axis labels dont merge
plt.xlabel('Race')
plt.ylabel('Percent Below Poverty')
plt.show()

# %% [markdown]
# Here, you can see that certain races have higher 'Percent Below Poverty' points than others and in higher numbers. In other words, certain races have higher poverty rates and in higher amounts. Thus, a relationship does exist between poverty and race.

# %% [markdown]
# Next, we're going to make a plot that shows Percent Below Poverty vs. Year, but we'll keep our color coding so we can distinguish by race.

# %% [markdown]
# To do this, we kept our grouping from the previous plot, but made a new plot and changed 'x' to 'Year'.

# %% [markdown]
# #### Poverty, Race, and Time

# %% [markdown]
# Next, we're going to make a plot that shows Percent Below Poverty vs. Year, but we'll keep our color coding so we can distinguish by race.

# %% [markdown]
# To do this, we kept our grouping from the previous plot, but made a new plot and changed 'x' to 'Year'.

# %%
fig, ax = plt.subplots(figsize=(7, 7))
for key, group in groupedDF :
        group.plot(ax = ax, kind='scatter', y='Percent Below Poverty', x='Year', label=key,color=colors[key])

plt.xlabel('Year')
plt.ylabel('Percent Below Poverty')
plt.show()

# %% [markdown]
# This graph once again indicates that poverty rates are higher for certain races than for others consistently across time, but also now shows that since 1960, poverty rates  -- although fluctuating -- across the board have been steadily been decreasing. Another interesting observation is that trend of poverty with time in this plot differs from our first plot. Since we've significantly expanded the time frame, we have a bigger view of poverty and time, showing that although fluctuations exist, there is still an overall trend that take place across 60 years.

# %% [markdown]
# To see what the trend would look like for each race, we'll use sklearns linear regression function to plot a fitted line for each race. Documentation for the function can be found here: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html.
#
# Here's the process we'll utilize:
# 1. Create a dataframe that will group the data by race using pandas groupby().
# 2. Iterate through the the dataframe rows by group.
# 3. For each group fit a linear regression with 'Year' as the x-axis and 'Percent Below Poverty' as the y.
# 4. Plot the predicted regression for each group.
#
# We've printed out the coefficient and intercept of each fitted line just in case it'll be handy later on.

# %% [markdown]
# The following graph illustrates that despite the decrease in pverty generally over time, generally, Hispanic, Black, and Native American people are more likely to experiecne poverty. The lines also are prediction lines that illustrate predicted percentage below poverty every year based on their race.

# %%
finalDF['Prediction'] = " "
groupedDF = finalDF.groupby(['Race'])
fig, ax = plt.subplots(figsize=(7, 7))
predictions = {"Year":[], "American Indian/AN" : [], "Hispanic" : [], "Black" :[], "White": [] , "Asian/Pacific Islander" : []}
predictionsF = {"Year":[], "American Indian/AN" : [], "Hispanic" : [], "Black" :[], "White": [] , "Asian/Pacific Islander" : []}
for key, group in groupedDF :
    group.plot(ax = ax, kind='scatter', y='Percent Below Poverty', x='Year', label=key,color=colors[key])
    x = group['Year'].to_numpy().reshape(-1,1) #saving as valye bc will be using
    reg = LinearRegression().fit(x, group['Percent Below Poverty'].to_numpy().reshape(-1,1))
    regF = LinearRegression().fit(x, group['Percent Female HoH Below Poverty'].to_numpy().reshape(-1,1))
    race_y_pred = reg.predict(x) #using regression to predict values of y given values of x (can compare this prediction to actual)
    race_yF_pred = regF.predict(x)
    predictions [key].append(race_y_pred) 
    predictions['Year'] = x.astype(int)
    predictionsF[key].append(race_yF_pred)
    predictionsF['Year'] = x.astype(int)
    plt.plot(x,race_y_pred, color = colors[key],  label = str(key) +  " RL")
    print(key +":" + str(reg.intercept_) + "," + str(reg.coef_)) #save for later

plt.xlabel('Year')
plt.ylabel('Percent Below Poverty')
plt.show()


# how to plot predicted values for each group?
print(finalDF.head())
# Out:
# American Indian/AN:[343.4226586],[[-0.15840149]]
# Asian/Pacific Islander:[336.60689782],[[-0.16201369]]
# Black:[525.74970826],[[-0.24937306]]
# Hispanic:[296.99674322],[[-0.13658207]]
# White:[-33.33509618],[[0.02210022]]
#    Year  Total Number  Number Below Poverty  Percent Below Poverty Female HoH  \
# 0  2021         62482                 10690                   17.1      12382
# 1  2020         61769                 10520                   17.0      12856
# 2  2019         60602                  9545                   15.7      12248
# 3  2018         59957                 10526                   17.6      11939
# 4  2017         59051                 10816                   18.3      12155
#
#    Percent Female HoH Below Poverty      Race Percent Female HoH Prediction
# 0                              30.3  Hispanic          19.816907
# 1                              30.1  Hispanic          20.813029
# 2                              28.7  Hispanic          20.210554
# 3                              31.1  Hispanic          19.912604
# 4                              35.2  Hispanic          20.583902

# %% [markdown]
# Now, we're going to use statsmodels ols() function to get a linear regression of Percent Below Poverty ~ Race (essentially, PBP vs Race) and then summer() to print out the results. We're doing this to get a numerical representation of the relationships between Race and PBP to see if race is a statistically significant predictor of poverty.
#
# More information on these functions can be found here https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html.

# %%
res = smf.ols(formula= "Q(\"Percent Below Poverty\") ~ Race ", data=finalDF).fit()
print(res.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Q("Percent Below Poverty")   R-squared:                       0.835
# Model:                                    OLS   Adj. R-squared:                  0.832
# Method:                         Least Squares   F-statistic:                     297.5
# Date:                        Fri, 12 May 2023   Prob (F-statistic):           1.06e-90
# Time:                                17:45:01   Log-Likelihood:                -627.90
# No. Observations:                         240   AIC:                             1266.
# Df Residuals:                             235   BIC:                             1283.
# Df Model:                                   4
# Covariance Type:                    nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         25.8919      0.550     47.067      0.000      24.808      26.976
# Race[T.Asian/Pacific Islander]   -14.0568      0.778    -18.068      0.000     -15.589     -12.524
# Race[T.Black]                      2.1772      0.711      3.060      0.002       0.776       3.579
# Race[T.Hispanic]                  -1.6784      0.720     -2.332      0.021      -3.096      -0.261
# Race[T.White]                    -15.1648      0.702    -21.611      0.000     -16.547     -13.782
# ==============================================================================
# Omnibus:                        1.845   Durbin-Watson:                   0.357
# Prob(Omnibus):                  0.398   Jarque-Bera (JB):                1.669
# Skew:                          -0.203   Prob(JB):                        0.434
# Kurtosis:                       3.042   Cond. No.                         6.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Considering that the probablity of the F-statistic (p-value) is close to 0, except for Hispanic, the null hypothesis of no relationship between race and percent below poverty is less likely to be valid. Therefore, we should utilize the predictions previously calculated to find how race correlates with the amount of percent below poverty each year.

# %% [markdown]
# Next, we will go back to those predicted values and make a data frame out of them.
#
# We will include predictions of Percent below poverty and percent below poverty under households headed solely by women.

# %%
predicts = pd.DataFrame(map(np.ravel, predictions.values()), index=predictions.keys()).T
predictsF = pd.DataFrame(map(np.ravel, predictionsF.values()), index=predictionsF.keys()).T


newPredicts = pd.DataFrame({"Prediction" : pd.concat([predicts["Hispanic"].loc[0:51], predicts["White"], 
                predicts["Asian/Pacific Islander"].loc[0:36], predicts["Black"].loc[0:58], predicts["American Indian/AN"].loc[0:36]], ignore_index=True),
                            "Prediction Female HoH":pd.concat([predictsF["Hispanic"].loc[0:51], predictsF["White"], 
                predictsF["Asian/Pacific Islander"].loc[0:36], predictsF["Black"].loc[0:58], predictsF["American Indian/AN"].loc[0:36]], ignore_index=True)})
newPredicts["Race"] = ""
newPredicts["Race"].loc[0:51] = "Hispanic"
newPredicts["Race"].loc[52:116] = "White"
newPredicts["Race"].loc[117:153] = "Asian/Pacific Islander"
newPredicts["Race"].loc[154:212] = "Black"
newPredicts["Race"].loc[213:] = "American Indian/AN"

newPredicts["Year"] = finalDF["Year"]

# newPredicts = newPredicts.iloc[::-1]

newPredicts
# Out:
#      Prediction  Prediction Female HoH                Race    Year
# 0     20.964384              33.145018            Hispanic  2021.0
# 1     21.100966              33.696399            Hispanic  2020.0
# 2     21.237548              34.247781            Hispanic  2019.0
# 3     21.374130              34.799162            Hispanic  2018.0
# 4     21.510713              35.350544            Hispanic  2017.0
# ..          ...                    ...                 ...     ...
# 239   28.045296              48.819757  American Indian/AN  1987.0
# 240   28.203697              49.220813  American Indian/AN     NaN
# 241   28.362099              49.621868  American Indian/AN     NaN
# 242   28.520500              50.022924  American Indian/AN     NaN
# 243   28.678902              50.423980  American Indian/AN     NaN
#
# [244 rows x 4 columns]

# %% [markdown]
# To have all the informaiton in one place, we'll add our predictions to our original df.

# %%
finalDF["Prediction"] = newPredicts["Prediction"].astype(float)
finalDF
# Out:
#      Year  Total Number  Number Below Poverty  Percent Below Poverty  \
# 0    2021         62482                 10690                   17.1
# 1    2020         61769                 10520                   17.0
# 2    2019         60602                  9545                   15.7
# 3    2018         59957                 10526                   17.6
# 4    2017         59051                 10816                   18.3
# ..    ...           ...                   ...                    ...
# 235  1991          1793                   562                   31.3
# 236  1990          1560                   444                   28.5
# 237  1989          1445                   345                   23.9
# 238  1988          1454                   440                   30.2
# 239  1987          1345                   387                   28.8
#
#     Female HoH  Percent Female HoH Below Poverty                Race  \
# 0        12382                              30.3            Hispanic
# 1        12856                              30.1            Hispanic
# 2        12248                              28.7            Hispanic
# 3        11939                              31.1            Hispanic
# 4        12155                              35.2            Hispanic
# ..         ...                               ...                 ...
# 235        347                              59.6  American Indian/AN
# 236        334                              54.1  American Indian/AN
# 237        269                              56.5  American Indian/AN
# 238        269                              42.9  American Indian/AN
# 239        325                              48.4  American Indian/AN
#
#     Percent Female HoH  Prediction
# 0            19.816907   20.964384
# 1            20.813029   21.100966
# 2            20.210554   21.237548
# 3            19.912604   21.374130
# 4            20.583902   21.510713
# ..                 ...         ...
# 235           19.35304   27.411690
# 236          21.410256   27.570091
# 237          18.615917   27.728493
# 238          18.500688   27.886894
# 239          24.163569   28.045296
#
# [240 rows x 9 columns]

# %% [markdown]
# To visually guage the accuracy of the predictons made from the linear regression, we'll create a violin plot of the residuals. We'll use pythons seaborn package. Here's a detailed descriptions of seaborns violinplot() functions: https://seaborn.pydata.org/generated/seaborn.violinplot.html.
#
# We've started by creating the plot. Then we set the style and used ols's resid attribute to obtain the residuals of the linear regression. Then we used violinplot() to creat the plot with Race as x and Residuals as y.

# %%
fig, ax = plt.subplots(figsize=(5,5))
sb.set(style = 'whitegrid') 
finalDF['Residuals'] = res.resid
sb.violinplot( data = finalDF, x= 'Race', y='Residuals') 
plt.xticks(rotation=50, ha='right')
plt.xlabel('Race')
plt.ylabel('Residuals')
finalDF
# Out:
#      Year  Total Number  Number Below Poverty  Percent Below Poverty  \
# 0    2021         62482                 10690                   17.1
# 1    2020         61769                 10520                   17.0
# 2    2019         60602                  9545                   15.7
# 3    2018         59957                 10526                   17.6
# 4    2017         59051                 10816                   18.3
# ..    ...           ...                   ...                    ...
# 235  1991          1793                   562                   31.3
# 236  1990          1560                   444                   28.5
# 237  1989          1445                   345                   23.9
# 238  1988          1454                   440                   30.2
# 239  1987          1345                   387                   28.8
#
#     Female HoH  Percent Female HoH Below Poverty                Race  \
# 0        12382                              30.3            Hispanic
# 1        12856                              30.1            Hispanic
# 2        12248                              28.7            Hispanic
# 3        11939                              31.1            Hispanic
# 4        12155                              35.2            Hispanic
# ..         ...                               ...                 ...
# 235        347                              59.6  American Indian/AN
# 236        334                              54.1  American Indian/AN
# 237        269                              56.5  American Indian/AN
# 238        269                              42.9  American Indian/AN
# 239        325                              48.4  American Indian/AN
#
#     Percent Female HoH  Prediction  Residuals
# 0            19.816907   20.964384  -7.113462
# 1            20.813029   21.100966  -7.213462
# 2            20.210554   21.237548  -8.513462
# 3            19.912604   21.374130  -6.613462
# 4            20.583902   21.510713  -5.913462
# ..                 ...         ...        ...
# 235           19.35304   27.411690   5.408108
# 236          21.410256   27.570091   2.608108
# 237          18.615917   27.728493  -1.991892
# 238          18.500688   27.886894   4.308108
# 239          24.163569   28.045296   2.908108
#
# [240 rows x 10 columns]

# %% [markdown]
# The results are consistent with what the residuals of a linear regression should look like.
# -  A median close to 0
# - Majority participation about the mean
# - Small range, with lower participation near extremes
# - Unimodal distribution

# %% [markdown]
# Our most recent plot did indicate a simultaneous trend between time and poverty, so now we'll complete another linear regression with year as an interaction term with race using ':'.

# %%
res2 = smf.ols(formula= "Q(\"Percent Below Poverty\") ~ Race:Year ", data=finalDF).fit()
print(res2.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Q("Percent Below Poverty")   R-squared:                       0.874
# Model:                                    OLS   Adj. R-squared:                  0.872
# Method:                         Least Squares   F-statistic:                     325.6
# Date:                        Fri, 12 May 2023   Prob (F-statistic):          3.21e-103
# Time:                                17:45:02   Log-Likelihood:                -595.28
# No. Observations:                         240   AIC:                             1203.
# Df Residuals:                             234   BIC:                             1223.
# Df Model:                                   5
# Covariance Type:                    nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                           253.8624     26.612      9.539      0.000     201.433     306.292
# Race[American Indian/AN]:Year        -0.1137      0.013     -8.565      0.000      -0.140      -0.088
# Race[Asian/Pacific Islander]:Year    -0.1207      0.013     -9.094      0.000      -0.147      -0.095
# Race[Black]:Year                     -0.1131      0.013     -8.485      0.000      -0.139      -0.087
# Race[Hispanic]:Year                  -0.1150      0.013     -8.629      0.000      -0.141      -0.089
# Race[White]:Year                     -0.1219      0.013     -9.135      0.000      -0.148      -0.096
# ==============================================================================
# Omnibus:                        3.373   Durbin-Watson:                   0.409
# Prob(Omnibus):                  0.185   Jarque-Bera (JB):                2.332
# Skew:                           0.006   Prob(JB):                        0.312
# Kurtosis:                       2.517   Cond. No.                     1.39e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.39e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# A p-value that's nearly 0 and a large F-statistic (thats actually larger than our first linear regression) indicate that there is a statistically significant relationship between Poverty, Race, and Year, such that we can reject the null hypothesis. In other words, race and year are statistically significant predictors of poverty.

# %% [markdown]
# Now lets create another violin plot using the same strategy as above to see how accurate and precise our linear regression is.

# %%
fig, ax = plt.subplots(figsize=(5,5))
sb.set(style = 'whitegrid') 
finalDF['Residualsw/Time'] = res2.resid
sb.violinplot( data = finalDF, x= 'Race', y='Residualsw/Time') 
plt.xticks(rotation=50, ha='right')
plt.xlabel('Race')
plt.ylabel('Residuals')
finalDF.head() #lets see our new column
# Out:
#    Year  Total Number  Number Below Poverty  Percent Below Poverty Female HoH  \
# 0  2021         62482                 10690                   17.1      12382
# 1  2020         61769                 10520                   17.0      12856
# 2  2019         60602                  9545                   15.7      12248
# 3  2018         59957                 10526                   17.6      11939
# 4  2017         59051                 10816                   18.3      12155
#
#    Percent Female HoH Below Poverty      Race Percent Female HoH  Prediction  \
# 0                              30.3  Hispanic          19.816907   20.964384
# 1                              30.1  Hispanic          20.813029   21.100966
# 2                              28.7  Hispanic          20.210554   21.237548
# 3                              31.1  Hispanic          19.912604   21.374130
# 4                              35.2  Hispanic          20.583902   21.510713
#
#    Residuals  Residualsw/Time
# 0  -7.113462        -4.375819
# 1  -7.213462        -4.590805
# 2  -8.513462        -6.005791
# 3  -6.613462        -4.220777
# 4  -5.913462        -3.635763

# %% [markdown]
# The results of the linear regression residuals are relatively the same as our first violin plot, except for the 'White' group which has a wider distribution. The assumptions of a linear regression still remain for this plot as they did for our first violin plot.

# %% [markdown]
# Next, we'll fit the linear regression model for the predicted values vs Race interacting with the "Percent Below Poverty" to get a better idea of whether percent below poverty has a statistically significant impact on predictions of this value.

# %%
# Residual plot for the fitted values
sb.residplot(data=finalDF, x= "Percent Below Poverty",
             y="Residuals").set(
                 title="Residuals vs Fitted Values Model")
# Out:
# [Text(0.5, 1.0, 'Residuals vs Fitted Values Model')]

# %% [markdown]
# These results show that our previous regression model was likely not a good fit. The linear pattern fo the graph indicates a non linear relationship. This may be due to a lack of proper testing or complexity in inour model, so we will hold our judgement until after we implement more complexity.

# %%
finalDF["Residuals_for_Predicted"] = res2.resid

sb.violinplot( data = finalDF, x= 'Race', 
              y='Residuals_for_Predicted') 
plt.xlabel('Race')
plt.ylabel('Residuals for Predicted')
# Out:
# Text(0, 0.5, 'Residuals for Predicted')

# %% [markdown]
# The results of this violin plot show skinnier plots than previously. This usually indicates lower probability, so in our case it means the probability that our predictions accurately predict percent below poverty is relatively low.
#
# The residual plot below supports this idea due to its right skew. However it is quite scattered, so our predictions are likely not entirely off.

# %%
# Residual plot for the fitted values
sb.residplot(data=finalDF, x= "Percent Below Poverty", 
             y="Residuals").set(title="Residuals vs Fitted Values Model")
# Out:
# [Text(0.5, 1.0, 'Residuals vs Fitted Values Model')]

# %% [markdown]
# These results show that our previous regression model was likely not a good fit. The linear pattern fo the graph indicates a non linear relationship. This may be due to a lack of proper testing or complexity in inour model, so we will hold our judgement until after we implement more complexity.

# %%
finalDF["Residuals_for_Predicted"] = res2.resid

sb.violinplot( data = finalDF, x= 'Race', y='Residuals_for_Predicted') 
plt.xlabel('Race')
plt.ylabel('Residuals for Predicted')
# Out:
# Text(0, 0.5, 'Residuals for Predicted')

# %% [markdown]
# The results of this violin plot show skinnier plots than previously. This usually indicates lower probability, so in our case it means the probability that our predictions accurately predict percent below poverty is relatively low.
#
# The residual plot below supports this idea due to its right skew. However it is quite scattered, so our predictions are likely not entirely off.

# %%
sb.residplot(data=finalDF, x= "Percent Below Poverty", 
                  y="Residuals_for_Predicted").set(title="Residuals for Predicted vs Fitted Values Model")
# Out:
# [Text(0.5, 1.0, 'Residuals for Predicted vs Fitted Values Model')]

# %% [markdown]
# Although our predictions were likely somewhat accurate as demonstrated by the somewhat scattered plot, our goal now is to increase the accuracy of our predictions as much as possible.

# %% [markdown]
# Before we start implementing machine learning to better understand the data, we need a couple of pieces of data.
# First we need to standardize percent below poverty. This is the formula we will use:
#
# ([Percent Below Poverty] - mean[Percent Below Poverty]) / standard_deviation[Percent Below Poverty]
#
# Source: https://en.wikipedia.org/wiki/Standard_score
#
# Then we will train on 95% of the data and drop the extra 5% since we are working with a standardized dataset, we will be working with the 95% confidence interval.
#
# Finally we will fit the regression model of the standarized data of Percent Below Poverty and see its relationhship to race and how that interacts with the perecntage of female HoH Below Poverty.

# %%
# Get mean and standard deviations of percent below poverty
mean = finalDF["Percent Below Poverty"].mean()
std = finalDF["Percent Below Poverty"].std()

# Obtain the standardized values for the percent below poverty for each datapoint
finalDF["Percent_Below_Poverty_std"] = (finalDF["Percent Below Poverty"] - mean) / std   

# Sample 95% of the data for 95% confidence interval
final_train = finalDF.sample(frac=0.95)
final_test = finalDF.drop(final_train.index)

# Print fitted linear regression of relation between percent below poverty standardized and race and percent female head
# of house hold
newRes = smf.ols(formula="Percent_Below_Poverty_std ~ Race + Q(\"Percent Female HoH Below Poverty\")", data=final_train).fit()
print(newRes.summary())
# Out:
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     Percent_Below_Poverty_std   R-squared:                       0.950
# Model:                                   OLS   Adj. R-squared:                  0.949
# Method:                        Least Squares   F-statistic:                     847.5
# Date:                       Fri, 12 May 2023   Prob (F-statistic):          1.96e-142
# Time:                               17:45:04   Log-Likelihood:                 17.303
# No. Observations:                        228   AIC:                            -22.61
# Df Residuals:                            222   BIC:                            -2.030
# Df Model:                                  5
# Covariance Type:                   nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                -1.3203      0.100    -13.199      0.000      -1.517      -1.123
# Race[T.Asian/Pacific Islander]           -0.7019      0.072     -9.806      0.000      -0.843      -0.561
# Race[T.Black]                             0.1415      0.051      2.783      0.006       0.041       0.242
# Race[T.Hispanic]                         -0.3196      0.051     -6.285      0.000      -0.420      -0.219
# Race[T.White]                            -1.1511      0.059    -19.595      0.000      -1.267      -1.035
# Q("Percent Female HoH Below Poverty")     0.0468      0.002     21.940      0.000       0.043       0.051
# ==============================================================================
# Omnibus:                       28.142   Durbin-Watson:                   1.787
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.368
# Skew:                          -0.627   Prob(JB):                     9.48e-13
# Kurtosis:                       5.063   Cond. No.                         338.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# __Machine Learning__
#
# Compare machine learning model results to previous model results
#
# First we will run our data through a gradient descent algorithm.
#
# Gradient descent in machine learning is an optimization algorithm whic uses training data to learn over time and devlop things like neural networks. More information ont his powerful AI tool can be found here: [IBM Source](https://www.ibm.com/topics/gradient-descent#:~:text=Gradient%20descent%20is%20an%20optimization,each%20iteration%20of%20parameter%20updates)

# %%
# First we need our independendent and dependednt variables

# Dependendent
y = final_test["Percent_Below_Poverty_std"].to_numpy()

# Independent
X = sm.add_constant(final_test[['Percent Below Poverty', 'Percent Female HoH Below Poverty']].to_numpy())

# Gradient descent algorithm
gradientRegress = slm.SGDRegressor(eta0=0.00001).fit(X,y)

# Obtain the coefficents
gradientTheta = gradientRegress.coef_

# %%
# Make a dataframe that takes our previous test results
final = final_test[['Race','Percent Below Poverty', 'Percent Female HoH Below Poverty', 'Percent_Below_Poverty_std', 'Prediction']].copy().reset_index(drop=True)

# Add our gradient predictions by applying the coeefecints to a doproduct against the values from the 
# Indepdnednt values and "un"-standardize the values
final['Gradient Prediction'] = (pd.Series([gradientTheta.dot(row) for row in X]) * std) + mean

# To see how much the models (both our initial and the gradient predictions) 
# were off by, get the difference between them and the actual percent below poverty
final['Model Miss'] = abs(final['Prediction'] - final['Percent Below Poverty'])
final['Gradient Miss'] = abs(final['Gradient Prediction'] - final['Percent Below Poverty'])

# Print out final table
final
# Out:
#                       Race  Percent Below Poverty  \
# 0                 Hispanic                   22.4
# 1                 Hispanic                   23.0
# 2                    White                   10.5
# 3                    White                   11.7
# 4   Asian/Pacific Islander                   14.0
# 5                    Black                   19.5
# 6                    Black                   19.6
# 7                    Black                   27.4
# 8                    Black                   33.3
# 9       American Indian/AN                   23.2
# 10      American Indian/AN                   26.4
# 11      American Indian/AN                   29.2
#
#     Percent Female HoH Below Poverty  Percent_Below_Poverty_std  Prediction  \
# 0                               56.7                   0.277568   26.973995
# 1                               53.1                   0.351002   27.383741
# 2                               25.6                  -1.178862   10.931639
# 3                               31.8                  -1.031995   10.732737
# 4                               33.6                  -0.750500   13.065563
# 5                               30.8                  -0.077360   21.766754
# 6                               29.9                  -0.065121   22.016127
# 7                               41.0                   0.889514   24.509857
# 8                               58.1                   1.611610   33.986034
# 9                               42.7                   0.375480   25.986077
# 10                              45.0                   0.767125   26.936485
# 11                              47.1                   1.109815   27.253288
#
#     Gradient Prediction  Model Miss  Gradient Miss
# 0             23.091469    4.573995       0.691469
# 1             22.968934    4.383741       0.031066
# 2             21.480774    0.431639      10.980774
# 3             21.763987    0.967263      10.063987
# 4             21.909286    0.934437       7.909286
# 5             21.976659    2.266754       2.476659
# 6             21.944410    2.416127       2.344410
# 7             22.634112    2.890143       4.765888
# 8             23.498951    0.686034       9.801049
# 9             22.565389    2.786077       0.634611
# 10            22.759488    0.536485       3.640512
# 11            22.932775    1.946712       6.267225

# %%
# print mean miss rates
print("Model Miss Mean: ",  final["Model Miss"].mean())
print("Gradient Miss Mean: ",  final["Gradient Miss"].mean())
# Out:
# Model Miss Mean:  2.068283777266997
# Gradient Miss Mean:  4.967244482090084

# %% [markdown]
# The present data above illustrates a low chance that our model was innacurate. Our previous predictions and gradient result have a relatively low miss rate. There is still a chance the lack of data input may also be at play here, but the results demonstrate that the previously assumed relationship between not only poverty and race but also poverty race and it's interaction with pecent female head of household below poverty was correlary.

# %% [markdown]
# The following graph visuallizes the relationship between Percent below poverty and percent female head of household grouped by race.

# %%
groupedDF = finalDF.groupby(['Race'])
gf = finalDF.groupby(['Race'])
fig, ax = plt.subplots(figsize=(7, 7))
for key, group in gf :
    group.plot(ax = ax, kind='scatter', y='Percent Below Poverty', x='Percent Female HoH', label=key,color=colors[key])

plt.title('Percent Female HoH vs. Percent Below Poverty By Race')
plt.show()

# %% [markdown]
# There seems to be a linear relationship between these 2 variables. The more single parent households you see, th emore pverty is present. This graph also illustrates the racial divides of poverty with the black, Native American, and Hispanic populations seeing vastly higher rates of both single mother households and percent below poverty.

# %%
finalDF["Residuals for Predicted"] = newRes.resid

sb.violinplot( data = finalDF, x= 'Race', y='Residuals for Predicted') 
plt.xticks(rotation=50, ha='right')

plt.xlabel('Race')
plt.ylabel('Residuals for Predicted')
# Out:
# Text(0, 0.5, 'Residuals for Predicted')

# %% [markdown]
# Although the length of the plots may suggest some level of variability, the relaitvely high concentration of data toards the median indicates our regression model was likely a good fit.

# %%
sb.residplot(data=finalDF, x= "Percent Below Poverty", 
             y="Residuals for Predicted").set(title="Residuals for Predicted vs Fitted Values Model")
# Out:
# [Text(0.5, 1.0, 'Residuals for Predicted vs Fitted Values Model')]

# %% [markdown]
# The scatteredness of the final residual plot tells us that our model does illustrate a linear relationship between our predicted values for percent below poverty and actual percent below poverty, indicating that our predicted values we likely very accurate and generally mapped onto the reality of percentage below poverty among different the different racial groups.

# %% [markdown]
# # Table 6: Race and Hispanic Origin of People by Mean Income and Sex: 1947 to 2021

# %%
data6 = pd.read_excel("p03.xlsx", header = 9 ) #several headers, first one starts on line 9
print(data6.dtypes)
data6.head()
# Out:
# Unnamed: 0            object
# Unnamed: 1            object
# Current\ndollars      object
# 2021\ndollars         object
# Unnamed: 4            object
# Current\ndollars.1    object
# 2021\ndollars.1       object
# dtype: object
#   Unnamed: 0 Unnamed: 1 Current\ndollars 2021\ndollars Unnamed: 4  \
# 0       2021     118237            68592         68592     119263
# 1  2020 (41)     117931            64929         67961     118426
# 2       2019     116561            65144         69037     118731
# 3       2018     115219            61180         66011     116920
# 4  2017 (40)     114737            59735         66023     116468
#
#   Current\ndollars.1 2021\ndollars.1
# 0              45792           45792
# 1              43188           45204
# 2              43315           45903
# 3              39803           42946
# 4              38395           42437

# %%
# We mainly want to work with Male and Female Income in 2021 dollars. We will also take not of the amount of income earners for each group.

data6 = data6.rename(columns={"Unnamed: 0": "Year", "2021\ndollars": "Male_Income", "2021\ndollars.1": "Female_Income", "Unnamed: 1": "Amount_With_Income"})
data6 = data6.loc[:, ["Year", "Male_Income", "Female_Income","Amount_With_Income"]]
data6.head()
# Out:
#         Year Male_Income Female_Income Amount_With_Income
# 0       2021       68592         45792             118237
# 1  2020 (41)       67961         45204             117931
# 2       2019       69037         45903             116561
# 3       2018       66011         42946             115219
# 4  2017 (40)       66023         42437             114737

# %% [markdown]
# Concetrate on data for each race. Use melt to tidy up data.

# %%
# Tidy data for White subgroup

dWhite = data6.iloc[81:161,:]
dWhite['Race'] = 'White'
dWhite= dWhite.dropna()

# Melt data to make Race and gender categorical variables. This will be useful for our linear regression models.
dWhite = pd.melt(dWhite, id_vars=["Year", "Race", "Amount_With_Income"], value_vars=["Male_Income", "Female_Income"], value_name="Income", var_name="Gender")

dWhite
# Out:
#           Year   Race Amount_With_Income         Gender Income
# 0         2021  White              93506    Male_Income  71091
# 1    2020 (41)  White              93391    Male_Income  70345
# 2         2019  White              92667    Male_Income  71630
# 3         2018  White              91817    Male_Income  68622
# 4    2017 (40)  White              91559    Male_Income  68764
# ..         ...    ...                ...            ...    ...
# 137       1957  White              47833  Female_Income  15123
# 138       1956  White              47038  Female_Income  15253
# 139       1955  White              46586  Female_Income  15038
# 140       1954  White              45019  Female_Income  14654
# 141       1953  White              44991  Female_Income  14722
#
# [142 rows x 5 columns]

# %%
# Tidy data for Black subgroup

dBlack = data6.iloc[251:331,:]
dBlack['Race'] = 'Black'
dBlack= dBlack.dropna()
dBlack = pd.melt(dBlack, id_vars=["Year", "Race", "Amount_With_Income"], value_vars=["Male_Income", "Female_Income"], value_name="Income", var_name="Gender")

dBlack
# Out:
#           Year   Race Amount_With_Income         Gender Income
# 0         2021  Black              13631    Male_Income  47797
# 1    2020 (41)  Black              13606    Male_Income  47498
# 2         2019  Black              13164    Male_Income  47799
# 3         2018  Black              12932    Male_Income  44612
# 4    2017 (40)  Black              12876    Male_Income  44865
# ..         ...    ...                ...            ...    ...
# 137       1957  Black               5044  Female_Income   9147
# 138       1956  Black               4978  Female_Income   9202
# 139       1955  Black               4860  Female_Income   8326
# 140       1954  Black               4693  Female_Income   8660
# 141       1953  Black               4676  Female_Income   9004
#
# [142 rows x 5 columns]

# %%
# Tidy data for Asian subgroup

dAsian = data6.iloc[361:401,:]
dAsian['Race'] = 'Asian'
dAsian= dAsian.dropna()
dAsian = pd.melt(dAsian, id_vars=["Year", "Race", "Amount_With_Income"], value_vars=["Male_Income", "Female_Income"], value_name="Income", var_name="Gender")

dAsian
# Out:
#          Year   Race Amount_With_Income         Gender Income
# 0        2021  Asian               7255    Male_Income  85632
# 1   2020 (41)  Asian               7013    Male_Income  84606
# 2        2019  Asian               7010    Male_Income  85167
# 3        2018  Asian               6847    Male_Income  81913
# 4   2017 (40)  Asian               6771    Male_Income  79527
# ..        ...    ...                ...            ...    ...
# 67  1992 (22)  Asian               2558  Female_Income  32469
# 68       1991  Asian               2358  Female_Income  31101
# 69       1990  Asian               2235  Female_Income  31581
# 70       1989  Asian               2112  Female_Income  33295
# 71       1988  Asian               2123  Female_Income  30244
#
# [72 rows x 5 columns]

# %%
# Tidy data for Hispanic subgroup

dHispanic = data6.iloc[405:455,:]
dHispanic['Race'] = 'Hispanic'
dHispanic= dHispanic.dropna()
dHispanic = pd.melt(dHispanic, id_vars=["Year", "Race", "Amount_With_Income"], value_vars=["Male_Income", "Female_Income"], value_name="Income", var_name="Gender")

dHispanic
# Out:
#              Year      Race Amount_With_Income         Gender Income
# 0            2021  Hispanic              20158    Male_Income  48461
# 1       2020 (41)  Hispanic              19935    Male_Income  46415
# 2            2019  Hispanic              19352    Male_Income  46944
# 3            2018  Hispanic              18981    Male_Income  45613
# 4       2017 (40)  Hispanic              18544    Male_Income  44573
# ..            ...       ...                ...            ...    ...
# 95           1978  Hispanic               3447  Female_Income  18337
# 96           1977  Hispanic               3376  Female_Income  18329
# 97      1976 (17)  Hispanic               3099  Female_Income  17753
# 98      1975 (16)  Hispanic               2945  Female_Income  17438
# 99  1974 (16)(15)  Hispanic               3052  Female_Income  17774
#
# [100 rows x 5 columns]

# %% [markdown]
# Combine the data from each race into one dataframe

# %%
# Concetnate dataframes of each raec into one big datagrame
incData = pd.concat([ dHispanic ,dWhite , dAsian , dBlack], ignore_index=True, axis=0)

# Fix Year column as many entries have extra information besides just the year.
incData["Year"] = [year[0:4] for year in incData["Year"].astype(str)]
incData["Year"] = incData["Year"].astype(int)
incData["Income"] = incData["Income"].astype(int)
incData
# Out:
#      Year      Race Amount_With_Income         Gender  Income
# 0    2021  Hispanic              20158    Male_Income   48461
# 1    2020  Hispanic              19935    Male_Income   46415
# 2    2019  Hispanic              19352    Male_Income   46944
# 3    2018  Hispanic              18981    Male_Income   45613
# 4    2017  Hispanic              18544    Male_Income   44573
# ..    ...       ...                ...            ...     ...
# 451  1957     Black               5044  Female_Income    9147
# 452  1956     Black               4978  Female_Income    9202
# 453  1955     Black               4860  Female_Income    8326
# 454  1954     Black               4693  Female_Income    8660
# 455  1953     Black               4676  Female_Income    9004
#
# [456 rows x 5 columns]

# %%
# Color mappings for each race
colors = {"Hispanic" : "red", "Black" : "blue", "White": "purple" , "Asian" : "orange"}

# Specfically select for Male Income to plot
# Use Seaborn to make scatterplot
groupIncMen = incData.loc[incData["Gender"] == "Male_Income"]
sb.lmplot(x='Year', y='Income', data=groupIncMen, hue='Race', fit_reg=True, scatter=True).set(title='Income vs. Year By Race for Men')

# Specfically select for Female Income to plot
groupIncWomen = incData.loc[incData["Gender"] == "Female_Income"]
sb.lmplot(x='Year', y='Income', data=groupIncWomen, hue='Race', fit_reg=True, scatter=True).set(title='Income vs. Year By Race for Women')

# %% [markdown]
# There is something interesting to note about the data above. When accounting for gender, Black and hispanic men tend to do far worse than people of white or asian descent, however that distance is much narrower among women. This may suggest a shared experience between women that lead to them more often than not being treated more similarly across races compared to men. Women still maintain that Black and Hispanic people earn less and overall their earnings tend to be less then men, but that gap is a lot narrower than the one among men.
#
# Why might this be?
#
# Historically women have always seen some level of a wage gap. While it has narrowed over time, it still continues to persist in our society. According to the Center for American Progress, in 2020, white women earned 79 cents for every dollar a white man made. Black and Hispanic women made over 10 cents less than white women, illustrating how Race and Gender may be an inhibiting factor to one's income level. One piece of data persists though. Asian women tended to around the level or more income than their white male counterparts. We will discuss the socioeconomic implications of this data later on. [Source](https://www.americanprogress.org/article/women-of-color-and-the-wage-gap/)

# %%
# Fitted Linear regression model for relationsip between Income and Race and Gender 
incRes = smf.ols(formula='Income ~ Race * Gender', data=incData).fit()
print(incRes.summary())

incData["Residuals"] = incRes.resid
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Income   R-squared:                       0.717
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     162.0
# Date:                Fri, 12 May 2023   Prob (F-statistic):          1.83e-118
# Time:                        17:45:08   Log-Likelihood:                -4769.6
# No. Observations:                 456   AIC:                             9555.
# Df Residuals:                     448   BIC:                             9588.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                               4.191e+04   1419.175     29.532      0.000    3.91e+04    4.47e+04
# Race[T.Black]                          -1.796e+04   1742.203    -10.311      0.000   -2.14e+04   -1.45e+04
# Race[T.Hispanic]                       -1.692e+04   1861.231     -9.092      0.000   -2.06e+04   -1.33e+04
# Race[T.White]                          -1.384e+04   1742.203     -7.944      0.000   -1.73e+04   -1.04e+04
# Gender[T.Male_Income]                   2.611e+04   2007.017     13.009      0.000    2.22e+04    3.01e+04
# Race[T.Black]:Gender[T.Male_Income]    -1.592e+04   2463.847     -6.462      0.000   -2.08e+04   -1.11e+04
# Race[T.Hispanic]:Gender[T.Male_Income] -1.194e+04   2632.178     -4.536      0.000   -1.71e+04   -6765.303
# Race[T.White]:Gender[T.Male_Income]       50.8568   2463.847      0.021      0.984   -4791.277    4892.990
# ==============================================================================
# Omnibus:                       17.101   Durbin-Watson:                   0.209
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.374
# Skew:                          -0.086   Prob(JB):                       0.0152
# Kurtosis:                       2.359   Cond. No.                         15.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# All of the probabilites of the f-statistic are less than 5% implying that the null hypothesis of no relation between Income and the interaction between Race and Gender is likely to be the case. The r-squared value indicates that almost 71.1% of the level of income can be explained by Race and Gender indicating there being  a strong correlation between these 3 variables. This supports our previous expectation that throughout the years, one's gender and race correlate with their income. The average white male will make far more than the average hispanic male. The average male will see more income than women for every race indicated in the data.

# %%
sb.violinplot(data=groupIncMen, x="Race",
              y="Income").set(title="Income by Race for Men")
# Out:
# [Text(0.5, 1.0, 'Income by Race for Men')]

# %%
sb.violinplot(data=groupIncWomen, x="Race",
              y="Income").set(title="Income by Race for Women")
# Out:
# [Text(0.5, 1.0, 'Income by Race for Women')]

# %% [markdown]
# Based off The last 2 violin plots, barring Hispanic, Men tend to have less concentration around the means across the races as apposed to women who's data is more conectrated around the median. This indicates a higher level of variation of income among men within their respective races as apposed to women.
#
# So not only do men have more variation in income between races, but also within each race subset.
#
# Some things to note:
# - Asian women outperform Black men and slightly outperform Hispanic men
# - White men out perform every single category except for Asian men
#
# What may the socioeconomic factors be that lead to these outcomes of racial inequity?
#
# A case study we can observe would be the black population in America. Historically, being brought over as slaves and enduring decases of Jim Crow, Black people would not be given the opportunity to build wealth. On top of that, discriminatory housing practices such as the redlining that came about from the New Deal efforts would overall inhibit the population's progress in increasing wealth. Because of this, we see higher rates of poverty among this population which in many cases leads to many kids not going through with higher education as it would either be too expensive or would not immedately bring in money needed to pay off bills and make ends meet. Historical factors such explain why there exists such racial inequity in America. [Source](https://news.harvard.edu/gazette/story/2021/06/racial-wealth-gap-may-be-a-key-to-other-inequities/)
#
# In the case of Asian success, it is a little more complicated than what our data might lead one to believe. One factos to their success in America can be attributed to the fact many Asians are first or second generation immigrants. Immigrants more often than not have already attained higher education or have been well educated in some sort of trade ([Source](https://www.brookings.edu/research/asian-american-success-and-the-pitfalls-of-generalization/)). In addition, it is important to note "Asian" is an incredibly broad category. When we refer to the fact that Asian women outperform Black and hispanic men, much of this data influenced by the subsets of the Asian population that tend to earn more. Groups such as Indian, Taiwanese, Chinese, and Malaysian, tend to outperform many of their other ethnicitites such as Japanese, Bangladeshi, Thai, Vietnamese, etc. Many of which make up a much smaller population than the aforemention top earners.
#
# It's important to understand historical context behind the inequities between races in order to prevent biased reasoning to explain the differences.

# %% [markdown]
# __Residuals:__
# The following violin plot is a plot of the residuals measured previously from the linear regression analysis of income by Race interacting with Gender.

# %%
sb.violinplot(data=incData, x="Race", y="Residuals").set(title="Residuals by Race")
# Out:
# [Text(0.5, 1.0, 'Residuals by Race')]

# %% [markdown]
# The residual plot above illustrates that median values are all concentrated around 0 indicating that the aforementioned fitted linear regression is a good fit, however, due to the length of some of the plots, this indicates a signficant amount variation. Thus we can't in good faith say the model is best fit, so we need to work to alleviate this.
#
# To achieve a better model, we will utilize a basic machine learning model.

# %%
# Obtain mean income and the Income's standard deviation
mean = incData["Income"].mean()
std = incData["Income"].std()

# Standardize Income = (subtract each income value by the mean) / standard deviation
incData["Income_std"] = (incData["Income"] - mean) / std   

# Select the training to data to be 95% of the data
inc_train = incData.sample(frac=0.95)
inc_test = incData.drop(inc_train.index)

# Fit the regression model to see the relationship between standardized income and race and gender
inc_model = smf.ols(formula="Income_std ~ Race + Gender ",data=inc_test).fit()

# Print fitted regression model summary
print(inc_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Income_std   R-squared:                       0.631
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     7.693
# Date:                Fri, 12 May 2023   Prob (F-statistic):           0.000849
# Time:                        17:45:09   Log-Likelihood:                -19.275
# No. Observations:                  23   AIC:                             48.55
# Df Residuals:                      18   BIC:                             54.23
# Df Model:                           4
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.4806      0.632      0.760      0.457      -0.848       1.809
# Race[T.Black]            -1.4631      0.685     -2.136      0.047      -2.902      -0.024
# Race[T.Hispanic]         -1.3396      0.702     -1.910      0.072      -2.813       0.134
# Race[T.White]            -0.3792      0.692     -0.548      0.590      -1.832       1.074
# Gender[T.Male_Income]     0.8930      0.277      3.220      0.005       0.310       1.476
# ==============================================================================
# Omnibus:                        2.129   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.345   Jarque-Bera (JB):                1.665
# Skew:                          -0.640   Prob(JB):                        0.435
# Kurtosis:                       2.686   Cond. No.                         12.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# The simple regression model above tests for a relationship between the standard Income and Race and Gender. With p-values below 5% we reject the null hypothesis of no relation between these variables. This data also tells us that 78.4% of the standardized income can be explained by Race and Gender indicating a correlary relationship.

# %% [markdown]
# #### Poverty, Race, and Location

# %% [markdown]
# Here, we're going to use table to plot Income vs Race using the same functions as before.

# %% [markdown]
# At this point we've shown that Poverty varies by race and that a possible contributor is income. Now lets see the role that geography maybe.
#
# We'll now use to Table 4 to make a plot that represents Percent in Poverty vs State.

# %% [markdown]
# The current layout of table 4 makes this complicated, however.

# %%
povByRace.head(5)
# Out:
#         Location  White  Black  Hispanic  \
# 0  United States  0.095  0.217     0.176
# 1        Alabama  0.119  0.247     0.244
# 2         Alaska  0.078  0.251     0.130
# 3        Arizona  0.089  0.168     0.171
# 4       Arkansas  0.137  0.272     0.218
#
#    Asian/Native Hawaiian and Pacific Islander  American Indian/Alaska Native  \
# 0                                       0.102                          0.259
# 1                                       0.114                          0.144
# 2                                         NaN                          0.206
# 3                                       0.111                          0.348
# 4                                       0.116                          0.117
#
#    Multiple Races  Total
# 0           0.141  0.128
# 1           0.184  0.160
# 2           0.124  0.110
# 3           0.105  0.129
# 4           0.157  0.164

# %% [markdown]
# We're going to use pandas melt() to turn the 7 race columns to 1 column so that we can plot all the races and group by color. Additionally, this will allow us to use dropna() when there's nan values.
#
# Here's the information on how to use pandas melt: https://pandas.pydata.org/docs/reference/api/pandas.melt.html.
#
# Here's a helpful example as the documentation is unclear: https://www.geeksforgeeks.org/python-pandas-melt/

# %%
# color coding races
colors = {"American Indian/Alaska Native" : "green", "Hispanic" : "red", "Black" : "blue", "White": "purple" ,
          'Asian/Native Hawaiian and Pacific Islander': "orange"}
#choosing which new columns to make and which old columns to make the values of the new column
meltedPovByRace = pd.melt(povByRace, id_vars = ['Location'] , value_vars = ['White','Black','Hispanic', 'White',
                                                                           'Asian/Native Hawaiian and Pacific Islander',
                                                                           'American Indian/Alaska Native'],
                          var_name= ['Race'], value_name= 'Percent in Poverty')
# Note: we dont need the last 2 columns
meltedPovByRace = meltedPovByRace.dropna()
meltedPovByRace['Percent in Poverty'] = meltedPovByRace['Percent in Poverty'].astype(np.float16) #necessary for scatter plot to work

#using same graphing process as below
fig, ax = plt.subplots(figsize=(9, 9))
groupedByRace = meltedPovByRace.groupby(['Race'])
for key, group in groupedByRace :
    group.plot(ax=ax, kind='scatter', y='Percent in Poverty', x='Location', label=key,color=colors[key])

plt.xticks(rotation=50, ha='right')
plt.xlabel('State')
plt.ylabel('Percent in Poverty')

meltedPovByRace.head(10)
# Out:
#                Location   Race  Percent in Poverty
# 0         United States  White            0.094971
# 1               Alabama  White            0.119019
# 2                Alaska  White            0.078003
# 3               Arizona  White            0.088989
# 4              Arkansas  White            0.136963
# 5            California  White            0.090027
# 6              Colorado  White            0.077026
# 7           Connecticut  White            0.067993
# 8              Delaware  White            0.072998
# 9  District of Columbia  White            0.049988

# %% [markdown]
# If state did not have an affect on poverty, the scatter plots would be a in a straight line throughout the x-axis, but that is not the case. The fluctuations indicate that there is indeed an effect of state on poverty rates. In other words, poverty varies by race and this variations varies by state.

# %% [markdown]
# To confirm this theory, lets perform a linear regression.

# %%
res4= smf.ols(formula= "Q(\"Percent in Poverty\") ~  Race + Location", data=meltedPovByRace).fit()
print(res4.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Q("Percent in Poverty")   R-squared:                       0.711
# Model:                                 OLS   Adj. R-squared:                  0.618
# Method:                      Least Squares   F-statistic:                     7.685
# Date:                     Fri, 12 May 2023   Prob (F-statistic):           9.95e-26
# Time:                             17:45:11   Log-Likelihood:                 381.69
# No. Observations:                      232   AIC:                            -649.4
# Df Residuals:                          175   BIC:                            -452.9
# Df Model:                               56
# Covariance Type:                 nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                              0.2551      0.025     10.067      0.000       0.205       0.305
# Race[T.Asian/Native Hawaiian and Pacific Islander]    -0.1412      0.012    -11.508      0.000      -0.165      -0.117
# Race[T.Black]                                         -0.0272      0.012     -2.216      0.028      -0.051      -0.003
# Race[T.Hispanic]                                      -0.0784      0.012     -6.577      0.000      -0.102      -0.055
# Race[T.White]                                         -0.1607      0.012    -13.583      0.000      -0.184      -0.137
# Location[T.Alaska]                                    -0.0223      0.036     -0.617      0.538      -0.094       0.049
# Location[T.Arizona]                                    0.0038      0.034      0.111      0.912      -0.063       0.071
# Location[T.Arkansas]                                  -0.0016      0.034     -0.047      0.962      -0.069       0.065
# Location[T.California]                                -0.0212      0.034     -0.624      0.533      -0.088       0.046
# Location[T.Colorado]                                  -0.0456      0.034     -1.342      0.181      -0.113       0.021
# Location[T.Connecticut]                               -0.0310      0.036     -0.857      0.393      -0.102       0.040
# Location[T.Delaware]                                  -0.0240      0.036     -0.663      0.508      -0.095       0.047
# Location[T.District of Columbia]                      -0.0047      0.036     -0.131      0.896      -0.076       0.067
# Location[T.Florida]                                   -0.0192      0.034     -0.565      0.573      -0.086       0.048
# Location[T.Georgia]                                   -0.0026      0.034     -0.076      0.939      -0.070       0.065
# Location[T.Hawaii]                                    -0.0017      0.036     -0.047      0.962      -0.073       0.070
# Location[T.Idaho]                                     -0.0210      0.036     -0.583      0.561      -0.092       0.050
# Location[T.Illinois]                                  -0.0018      0.034     -0.053      0.957      -0.069       0.065
# Location[T.Indiana]                                    0.0118      0.036      0.327      0.744      -0.059       0.083
# Location[T.Iowa]                                       0.0520      0.034      1.529      0.128      -0.015       0.119
# Location[T.Kansas]                                     0.0098      0.036      0.272      0.786      -0.061       0.081
# Location[T.Kentucky]                                   0.0628      0.034      1.847      0.066      -0.004       0.130
# Location[T.Louisiana]                                  0.0468      0.034      1.376      0.171      -0.020       0.114
# Location[T.Maine]                                      0.0325      0.036      0.899      0.370      -0.039       0.104
# Location[T.Maryland]                                  -0.0400      0.036     -1.107      0.270      -0.111       0.031
# Location[T.Massachusetts]                             -0.0374      0.034     -1.100      0.273      -0.105       0.030
# Location[T.Michigan]                                  -0.0072      0.034     -0.212      0.832      -0.074       0.060
# Location[T.Minnesota]                                 -0.0080      0.034     -0.236      0.814      -0.075       0.059
# Location[T.Mississippi]                                0.0448      0.036      1.239      0.217      -0.027       0.116
# Location[T.Missouri]                                  -0.0144      0.034     -0.424      0.672      -0.082       0.053
# Location[T.Montana]                                    0.0206      0.039      0.523      0.602      -0.057       0.098
# Location[T.Nebraska]                                  -0.0180      0.034     -0.530      0.597      -0.085       0.049
# Location[T.Nevada]                                    -0.0142      0.034     -0.418      0.677      -0.081       0.053
# Location[T.New Hampshire]                             -0.0416      0.045     -0.920      0.359      -0.131       0.048
# Location[T.New Jersey]                                -0.0367      0.036     -1.017      0.311      -0.108       0.035
# Location[T.New Mexico]                                 0.0240      0.034      0.706      0.481      -0.043       0.091
# Location[T.New York]                                   0.0058      0.034      0.170      0.865      -0.061       0.073
# Location[T.North Carolina]                             0.0004      0.034      0.011      0.991      -0.067       0.067
# Location[T.North Dakota]                               0.0177      0.045      0.392      0.695      -0.071       0.107
# Location[T.Ohio]                                       0.0042      0.034      0.123      0.902      -0.063       0.071
# Location[T.Oklahoma]                                   0.0168      0.034      0.495      0.621      -0.050       0.084
# Location[T.Oregon]                                    -0.0134      0.034     -0.395      0.693      -0.081       0.054
# Location[T.Pennsylvania]                               0.0024      0.034      0.071      0.943      -0.065       0.070
# Location[T.Puerto Rico]                                0.2340      0.039      5.943      0.000       0.156       0.312
# Location[T.Rhode Island]                               0.0810      0.034      2.383      0.018       0.014       0.148
# Location[T.South Carolina]                             0.0148      0.034      0.435      0.664      -0.052       0.082
# Location[T.South Dakota]                               0.0879      0.036      2.435      0.016       0.017       0.159
# Location[T.Tennessee]                                  0.0027      0.036      0.076      0.939      -0.069       0.074
# Location[T.Texas]                                     -0.0192      0.034     -0.565      0.573      -0.086       0.048
# Location[T.United States]                             -0.0038      0.034     -0.112      0.911      -0.071       0.063
# Location[T.Utah]                                      -0.0088      0.034     -0.259      0.796      -0.076       0.058
# Location[T.Vermont]                                    0.0056      0.059      0.094      0.925      -0.111       0.123
# Location[T.Virginia]                                  -0.0360      0.036     -0.997      0.320      -0.107       0.035
# Location[T.Washington]                                -0.0282      0.034     -0.829      0.408      -0.095       0.039
# Location[T.West Virginia]                              0.0570      0.039      1.449      0.149      -0.021       0.135
# Location[T.Wisconsin]                                 -0.0042      0.034     -0.123      0.902      -0.071       0.063
# Location[T.Wyoming]                                    0.0486      0.039      1.234      0.219      -0.029       0.126
# ==============================================================================
# Omnibus:                       55.729   Durbin-Watson:                   2.218
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              276.201
# Skew:                           0.824   Prob(JB):                     1.06e-60
# Kurtosis:                       8.085   Cond. No.                         55.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Since our p-values were not below 5% we cannot reject the null hypothesis of no relation just yet. However, later on we will improve upon this model to get a more accurate model.

# %% [markdown]
# #### Income and Race

# %% [markdown]
# We've shown that there's a discrepincy in poverty rates between races, so now lets try to see why.
#
# One guess we have is possible variations in income.

# %%
colors = {"American Indian/AN" : "green", "Hispanic" : "red", "Black" : "blue", "White": "purple" ,
          "Asian/Pacific Islander" : "orange"}

fig, ax = plt.subplots(figsize=(5, 5))
plt.scatter(y= df['2021 Median Household Income'], x=df['Race/Ethnicity of Household Head'])

plt.xticks(rotation=45, ha='right') 
plt.xlabel('Race')
plt.ylabel('2021 Median Household Income')
plt.show()

# %% [markdown]
# The results in this plot do show fluctuations in income by race as the average changes drastically with each race. We wont get too deep into this trend other than showing that it exists.

# %% [markdown]
# ## Analysis, Hypothesis Testing, and Machine Learning
#
# The following will be a process we have seen previously. We will show a fitted linear regression model of the standardized data for percent in poverty. Following that we will use the standardized data to make a gradient descent model.

# %%
# Obtain mean Percent in Poverty and the Percent in Poverty's standard deviation
m = meltedPovByRace["Percent in Poverty"].mean()
s = meltedPovByRace["Percent in Poverty"].std()

# Standardize Percent in Poverty = (subtract each Percent in Poverty by the mean) / standard deviation
meltedPovByRace["Percent_in_Poverty_std"] = (meltedPovByRace["Percent in Poverty"] - m) / s   

# Select the training to data to be 95% of the data
pov_train = meltedPovByRace.sample(frac=0.95)
pov_test = meltedPovByRace.drop(pov_train.index)

# Melt data to properly make Location a cateogry that can act as an interaction term
pov_test = pov_test.melt( id_vars=["Race", "Percent in Poverty", "Percent_in_Poverty_std"], value_vars=["Location"], var_name="Location")
pov_test["Location"] = pov_test["Location"].astype(str)

# Fit the regression model to see the relationship between standardized Percent in Poverty and race and location
pov_model = smf.ols(formula="Percent_in_Poverty_std ~ Race : Location",data=pov_test).fit()

# Print fitted regression model summary
print(pov_model.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Percent_in_Poverty_std   R-squared:                       0.802
# Model:                                OLS   Adj. R-squared:                  0.689
# Method:                     Least Squares   F-statistic:                     7.093
# Date:                    Fri, 12 May 2023   Prob (F-statistic):             0.0131
# Time:                            17:45:12   Log-Likelihood:                -7.7990
# No. Observations:                      12   AIC:                             25.60
# Df Residuals:                           7   BIC:                             28.02
# Df Model:                               4
# Covariance Type:                nonrobust
# =========================================================================================================================================
#                                                                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 1.2544      0.429      2.923      0.022       0.240       2.269
# Race[T.Asian/Native Hawaiian and Pacific Islander]:Location[Location]    -2.2583      0.743     -3.039      0.019      -4.016      -0.501
# Race[T.Black]:Location[Location]                                          0.0232      0.607      0.038      0.971      -1.412       1.458
# Race[T.Hispanic]:Location[Location]                                      -1.0659      0.526     -2.028      0.082      -2.309       0.177
# Race[T.White]:Location[Location]                                         -2.2773      0.554     -4.111      0.005      -3.587      -0.967
# ==============================================================================
# Omnibus:                        0.032   Durbin-Watson:                   2.468
# Prob(Omnibus):                  0.984   Jarque-Bera (JB):                0.120
# Skew:                           0.015   Prob(JB):                        0.942
# Kurtosis:                       2.511   Cond. No.                         6.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# __Gradient Descent__

# %%
# First we need our independendent and dependednt variables

# Dependendent
y = pov_test["Percent_in_Poverty_std"].to_numpy()

# Independent
X = sm.add_constant(pov_test[['Percent in Poverty']].to_numpy())

# Gradient descent algorithm
gradientReg = slm.SGDRegressor(eta0=0.00001).fit(X,y)

# Obtain the coefficents
theta = gradientReg.coef_

# %%
# Make a datagrame that takes our previous test results
final_pov = pov_test[['Race','Location', 'Percent_in_Poverty_std', 'Percent in Poverty']].copy().reset_index(drop=True)

# Add our gradient predictions by applying the coeefecints to a doproduct against the values from the 
# Indepdnednt values and "un"-standardize the values
final_pov['Gradient Prediction'] = (pd.Series([theta.dot(row) for row in X]) * s) + m

# To see how much the was off by actual percentage in poverty
final_pov['Gradient Miss'] = abs(final_pov['Gradient Prediction'] - pov_test['Percent in Poverty'])

# Print out final table
final_pov
# Out:
#                                           Race  Location  \
# 0                                        White  Location
# 1                                        White  Location
# 2                                        White  Location
# 3                                        Black  Location
# 4                                        Black  Location
# 5                                     Hispanic  Location
# 6                                     Hispanic  Location
# 7                                     Hispanic  Location
# 8                                     Hispanic  Location
# 9   Asian/Native Hawaiian and Pacific Islander  Location
# 10               American Indian/Alaska Native  Location
# 11               American Indian/Alaska Native  Location
#
#     Percent_in_Poverty_std  Percent in Poverty  Gradient Prediction  \
# 0                -0.900391            0.094971             0.173344
# 1                -0.969238            0.088989             0.173344
# 2                -1.199219            0.068970             0.173344
# 3                 1.582031            0.311035             0.173345
# 4                 0.973145            0.258057             0.173345
# 5                -0.199219            0.156006             0.173344
# 6                 0.731934            0.237061             0.173345
# 7                 0.524414            0.218994             0.173345
# 8                -0.302979            0.146973             0.173344
# 9                -1.003906            0.085999             0.173344
# 10                0.375977            0.206055             0.173345
# 11                2.132812            0.358887             0.173345
#
#     Gradient Miss
# 0        0.078373
# 1        0.084355
# 2        0.104374
# 3        0.137690
# 4        0.084712
# 5        0.017338
# 6        0.063716
# 7        0.045650
# 8        0.026372
# 9        0.087346
# 10       0.032710
# 11       0.185542

# %%
print("Gradient miss: ", final_pov['Gradient Miss'].mean())
# Out:
# Gradient miss:  0.0790148268811729

# %% [markdown]
# As we can see, the miss rate of the predictions made from gradient descent are very low, indicating that this model is a good predictor of percentage in poverty by race and location.

# %% [markdown]
# # Insight and Policy
# The totality of the analysis in this tutorial has revealed significant themes in the existence of poverty in America. Through the collection, cleaning, processing, and analysis of each our tables we've been able to witness trends of poverty in America across time, race, and state that have allowed us to make generalizations about our society as a whole.
#
# Our analysis of poverty in America across time has shown that time alone is not an entirely accurate predictor of poverty. In general, poverty has decreased in the last few decades, however, the uncertainty and unpredictability of the world leaves us unable to guarantee how poverty will look in the next decade just by looking at the year. Any event can cause a drop and uproar in poverty rates.
#
# Our analysis of poverty by race shows that certain races are susceptible to higher poverty rates than others. Across the board, the White group consistently expereinced lower rates of poverty than the others, specifically, Black, Hispanic, or American Indian groups.
#
# Next, we've confirmed that the state in which one lives does also contribute to variations in poverty rates across races. That is, certain races will experience higher rates of poverty in some states than others.
#
# Finally, we've noticed that a trend in pay discrepncies across races that matched the trend in poverty across races.
#
# So in sum, we can say the following:
#
# - Black, American Indian, and Hispanic groups experience higher rates of poverty than White and Asian groups.
# - Black, American Indian, and Hispanic groups experience higher rates of poverty in certain states.
# - Black, American Indian, and Hispanic groups in average recieve lower incomes across the country than their White and Asian counterparts.
# - Poverty across time is inconsistent, but all races experiences similiar fluctuations across time.
#
# Now that we know these discrepenscies exist, it's our responsibility to take measures to diminish the role race has in poverty. It's our job as members of society to ensure all races have equal access to education, jobs, and wealth accumulation.
#
# Some ways we can go about implmenting equity, welfare and bring people of color out of poverty are:
# - Invest heavily in children
#     - Studies show that the rate of return on investment on a person's life is high at a younger ange than when they are older. They become much more likely to perform well in school and complete their education. These tend to be indicators that one's future won't be filled with poverty ([Source](https://reader.elsevier.com/reader/sd/pii/S1574069206010129?token=765AF0CCE8FAB996755A224F861B6DC82CFD5233BFFB9F8FC958C9D818530B6763583B5FA59AEB60175BF5F0815F070B&originRegion=us-east-1&originCreation=20230512065149)).
# - Closing the gender pay gap
#     - Many poverty striken households are led by single mothers. Despite this, not only do they have to work to feed their children, they get payed less on average than a man would. There are many ways to go about closing the pay gap.
#         - One way to lessen the gap would be to make paid maternal and paternal leave mandatory. Many companies will try to make sure they pay as little as possible for PTO, and parental leave tends to be quite a while. In many cases, this would lessen the chance of a woman attaing a certain position in the company due to the expectation of maternal leave. So making it an expecetation that men would also see time off as well would help alleviate this issue.
#     - Early investment in education for girls would also allow them to thrive in the future. We have seen as time has passed more an more women attaining higher education and their wages have reflected this. ([Source](https://skills4training.org/how-to-overcome-the-gender-pay-gap/))
# - Minimum Wage
#     - The American economy makes it difficult for people to argue for higher wages at times, so a means of alleviating this would be to increase the minimum wage to a more livable standard.
#     - $15/hr is something that has been floating around for a while. In general the goal would be that you would be able to not only live off your income, but have extra that can be used for other purposes.
#
# Overall, we hope this analysis is able to show the current state of affairs in terms of Poverty in America and how race plays a major role in it. Racial issues often intersect with other social issues like gender inequality, geographic differences, immigration problems and so forth. We've introduced some means of alleviating these problems and hope there is a strong enough political will to back these efforts.
#
# ------
#
# ## Sources
#
# 1. Britannica, T. Editors of Encyclopaedia (2023, April 6). poverty. Encyclopedia Britannica. https://www.britannica.com/topic/poverty
# 2. https://www.worldvision.ca/stories/child-sponsorship/what-is-poverty
# 3. https://www.cnbc.com/2023/03/07/why-poverty-might-be-far-worse-in-the-us-than-its-reported.html#:~:text=As%20of%20January%202021%2C%2037.9,the%20United%20States%20Census%20Bureau
# 4. https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html
# 5. https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
# 6. https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html
# 7. https://www.geeksforgeeks.org/implementing-web-scraping-python-beautiful-soup/
# 8. https://www.w3schools.com/python/ref_requests_get.asp
# 9. https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
# 10. https://en.wikipedia.org/wiki/Standard_score
# 11. https://www.americanprogress.org/article/women-of-color-and-the-wage-gap/
# 12. https://www.brookings.edu/research/asian-american-success-and-the-pitfalls-of-generalization/
# 13. https://news.harvard.edu/gazette/story/2021/06/racial-wealth-gap-may-be-a-key-to-other-inequities/
# 14. https://reader.elsevier.com/reader/sd/pii/S1574069206010129?token=765AF0CCE8FAB996755A224F861B6DC82CFD5233BFFB9F8FC958C9D818530B6763583B5FA59AEB60175BF5F0815F070B&originRegion=us-east-1&originCreation=20230512065149
# 15. https://skills4training.org/how-to-overcome-the-gender-pay-gap/
# 16. https://www.geeksforgeeks.org/python-pandas-melt/
# 17. https://pandas.pydata.org/docs/reference/api/pandas.melt.html
# 18. https://www.ibm.com/topics/gradient-descent#:~:text=Gradient%20descent%20is%20an%20optimization,each%20iteration%20of%20parameter%20updates
